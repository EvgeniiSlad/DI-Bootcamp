# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model_year", "origin", "car_name"]
df_mpg = pd.read_csv("auto-mpg.data", header=None, names=names, delim_whitespace=True)

# %%
df_mpg
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df_mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
data = pd.read_csv("auto-mpg.data", header=None, delim_whitespace=True)

# %%
data
# Out:
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
data = pd.read_csv("auto-mpg.data", header=None, names=names, delim_whitespace=True)

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## 10

# %%
plt.scatter(data['displacement'],data['acceleration'])
plt.xlabel('Displacement')
plt.ylabel('Acceleration')
# Out:
# Text(0, 0.5, 'Acceleration')

# %% [markdown]
# ## 11

# %%
toyota = data[(data['car_name'].str.contains('toyota')) & (data['model_year'] > 78)]
toyota.head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 310  38.1          4          89.0      60.00  1968.0          18.8
# 318  29.8          4         134.0      90.00  2711.0          15.5
# 321  32.2          4         108.0      75.00  2265.0          15.2
# 343  39.1          4          79.0      58.00  1755.0          16.9
# 348  37.7          4          89.0      62.00  2050.0          17.3
#
#      model_year  origin                car_name
# 310          80       3   toyota corolla tercel
# 318          80       3  toyota corona liftback
# 321          80       3          toyota corolla
# 343          81       3          toyota starlet
# 348          81       3           toyota tercel

# %%
not_toyota= data[(~data['car_name'].str.contains('toyota')) & (data['model_year'] > 78)]
not_toyota
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 280  21.5          6         231.0      115.0  3245.0          15.4
# 281  19.8          6         200.0      85.00  2990.0          18.2
# 282  22.3          4         140.0      88.00  2890.0          17.3
# 283  20.2          6         232.0      90.00  3265.0          18.2
# 284  20.6          6         225.0      110.0  3360.0          16.6
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin           car_name
# 280          79       1  pontiac lemans v6
# 281          79       1   mercury zephyr 6
# ...

# %%
plt.bar(not_toyota['model_year'],not_toyota['cylinders'], label='Not toyota')
plt.bar(toyota['model_year'],toyota['cylinders'], label='Toyota')
plt.legend()

# %% [markdown]
# ##  12

# %%
all_toyota = data[data['car_name'].str.contains('toyota')]
all_toyota
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 14   24.0          4         113.0      95.00  2372.0          15.0
# 31   25.0          4         113.0      95.00  2228.0          14.0
# 53   31.0          4          71.0      65.00  1773.0          19.0
# 57   24.0          4         113.0      95.00  2278.0          15.5
# 84   27.0          4          97.0      88.00  2100.0          16.5
# 108  20.0          4          97.0      88.00  2279.0          19.0
# 123  20.0          6         156.0      122.0  2807.0          13.5
# 131  32.0          4          71.0      65.00  1836.0          21.0
# 144  31.0          4          76.0      52.00  1649.0          16.5
# 167  29.0          4          97.0      75.00  2171.0          16.0
# 171  24.0          4         134.0      96.00  2702.0          13.5
# 205  28.0          4          97.0      75.00  2155.0          16.4
# 210  19.0          6         156.0      108.0  2930.0          15.5
# ...

# %%
plt.plot(all_toyota['model_year'],all_toyota['weight'],marker = 'o')

# %% [markdown]
# ##  13
